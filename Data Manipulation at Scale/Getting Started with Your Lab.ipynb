# %% [markdown]
# <h1>Getting Started with your Lab Sandbox</h1>
# <p>You can find important course-specific tips and notes for your Lab Sandbox in this <br>
#     quick guide to use throughout your course. You’ll be able to reference this at any time <br>
#     or visit the <a href="https://learner.coursera.help/hc/articles/360062301971">Learner Help Center</a>
#     for more info. </p>
#
# <h2>What tools are already installed in my sandbox environment?</h2>
# <ul>
#   <li>Python==2.7</li>
#   <li>scikit-learn(same as sklearn)==0.22.2.post1</li>
#   <li>pandas==1.0.3</li>
#   <li>numpy==1.18.4</li>
#   <li>matplotlib==3.2.1</li>
#   <li>R (create an R notebook from the "New" dropdown in your Jupyter home workspac</li>
#   <li>SQLite</li>
# </ul>
#
# <h2>Additional Course Specific Notes:</h2>
#
# <ul>
#     <li>Week 4 of this course covers a wide array of different Databases and tools at a high-level.
#     Please note that the Sandbox <br> is configured with all dependencies needed to complete your
#     required course work, but does not currently include <br>  tools such as Spark, Pig, and AWS tools.</li><br>
#     <li>You can complete the lab assignments related to Python, R, and SQLite sections within the Lab Sandbox environment</li><br>
#     <li><b>To optimize your notebook performance, please shut down each of your <br>
#         open/running Jupyter Notebooks after you complete them within your Lab</b>. <br>
#         This will provide full and dedicated system resources to the current lab assignment<br>
#         you are working on in your Lab Sandbox. If you experience any unexpected slow <br>
#         processing in your notebook, try to restart your Lab kernel and only open that single <br>
#         notebook to complete your work. You can learn more about restarting your Lab Sandbox <br>
#         and troubleshooting your lab in our Learner Help Center article <a href="https://learner.coursera.help/hc/articles/360044758731-Solving-Common-Issues-with-Coursera-Labs">here.</a></li><br>
#
# </ul>
# <ol>
#     <h2>Files Required for the Assignment</h2>
# <p>
# The  files required to complete the assignment can be download from the repository<br><a href="https://github.com/uwescience/datasci_course_materials.git">Github repository </a>
#     Visit the repository and download the materials as a zip file. Choose Download Zip.<br>
#   <img src="downloadzip.png"/><br>
#     You can upload the zip file to your Sandbox by using the <b>upload</b> option in the sandbox environment. Browse for your zip file and then click on upload.<br>
#     <li>Next, launch a new terminal by, clicking on <b>New(dropdown)</b> -><b>Terminal</b>. </li>
#     <li>Then  unzip the zip file by typing the following command in the terminal prompt
#   follows<br><br>
#     <code>unzip  datasci_course_materials-master</code><br>
#     <img src="unzipdata.png"/>
#     The files will be unzipped to your sandbox environment<br>
#     </p></li>
#
# </ol><br>
#
# <ol>
#     <h2> How to execute SQLite queries in the Lab Sandbox</h2><br>
#     <li>After launching the lab, Click on <b>New(dropdown)</b> -><b>Terminal</b> to open a new terminal. </li>
#     <li> Execute the following commands in the terminal to navigate to the folder of your assignment</li>
#     <code> cd  datasci_course_materials-master<br>
#         cd assignment2<br></code><br>
#         Create a newfile with a .sql extension (for example solution.sql) to answer sql questions in the assignment.<br>
#         Provide the answers for the questions in the form of sql queries (select statements for answering the questions )
#         <li>Later in the terminal type<br>
#             <strong>sqlite3 reuters.db < newfilename.sql </strong> </li>
#     Now, you will be able to execute the queries.
#     <br><br>
#     <b>To come out of sqlite you can press the Ctrl+D keys. </b>
# </ol>
#
# <h2>How to run Python in terminal in Lab Sandbox?</h2>
# <ol>
#     Type  <b>python2.7</b> followed by your filename. For example, python2.7 filename.py
#
# </ol>
#
# <h2>How to run Week1 Twitter Sentiment Analysis Assignment</h2>
# <p>
#     Use the <a href= "https://raw.githubusercontent.com/uwescience/datasci_course_materials/master/assignment1/three_minutes_tweets.json">sample dataset</a> to connect to twitter so you can build your own application.
#
#
#  Later in the twitterstream.py make the following changes in the fetch_samples method
#   </p>
#    <code>
#
#          import json
#          def fetchsamples():
#
#             tweets = []
#             for line in open('three_minutes_tweets.json', 'r'):
#                     tweets.append(json.loads(line))
#
#
#             response=json.dumps(tweets)
#             print response
#    </code>
#
#   <p>To run the file in the terminal navigate to the files uploaded as follows:
#     <img src="sandbox1.png"/>
#   </p>
#     <br>
#         <li>If anything is unclear regarding the course content, please go through the <br>
#         Discussion board and see if your question has been answered. If you have any issues <br>
#         with the Jupyter environment itself, please contact Coursera through the <a href="https://learner.coursera.help">Learner Help Center.</a></li><br>
# </ul>
